# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_name = r"E:\PhD\Data\Stefan\Best_GRP1\Pre_Processed\four_grp1_raw.xlsx"

df = pd.read_excel(file_name)

# %%
df = df.loc[df["Length (frames)"] > 10]
# df = df.loc[df["Average_Brightness"].between(3.1, 3.8)]
df = df.loc[df["MSD"].between(0, 3)]
df = df.drop_duplicates("MSD")
plt.hist(df["MSD"], bins=50)
plt.xticks(np.arange(0,3.1, 0.5), rotation=40)
plt.xlabel("MSD (um^2/sec)")
plt.ylabel("(Frequency (# of trajectories)")
plt.show()
